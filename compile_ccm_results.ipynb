# %%
import pandas as pd
import numpy as np
import xarray as xr
import glob

from scripts.compile_ccm_results import *

# %% [markdown]
# Test code that will eventually go into `scripts/compile_ccm_results.py`

# %%
t = 1
sst_outputs = np.sort(glob.glob('./outputs/SST/*tau_{}.csv'.format(t)))
# slp_outputs = np.sort(glob.glob('./outputs/SLP/*.csv'))

# %%
# def read_ccm_outputs(clim, t):
#     # reads outputs from CCM runs and compiles for clim {SST, SLP} for lags (tau) {1,3,6}
#     # returns one xarray for a clim and lag value
    
#     # create list of files 
#     outputs = np.sort(glob.glob('./outputs/{}/*tau_{}.csv'.format(clim, t)))

#     # create empty dataframe
#     df = pd.DataFrame()

#     # loop to read files in outputs
#     for f in outputs:
#         temp_df = pd.read_csv(f)

#         # concat each output to dataframe
#         df = pd.concat([df, temp_df], ignore_index=True)
        
#     # create multi-index df and convert to xarray DataArray with coords
#     df_multind = df.set_index(['eco_region', 'lon','lat'])
#     ccm_array = df_multind.to_xarray()
#     return(ccm_array)

# %%
ccm_sst_tau_1 = read_ccm_outputs('SST', 1)
ccm_sst_tau_3 = read_ccm_outputs('SST', 3)
ccm_sst_tau_6 = read_ccm_outputs('SST', 6)

# %%
ccm_slp_tau_1 = read_ccm_outputs('SLP', 1)
ccm_slp_tau_3 = read_ccm_outputs('SLP', 3)
ccm_slp_tau_6 = read_ccm_outputs('SLP', 6)

# %%
ccm_sst_tau_1
# Out:
# <xarray.Dataset>
# Dimensions:     (eco_region: 15, lon: 5, lat: 5)
# Coordinates:
#   * eco_region  (eco_region) object 'Arizona/New Mexico Mountains' ... 'Wasat...
#   * lon         (lon) float64 180.0 182.0 184.0 186.0 188.0
#   * lat         (lat) float64 52.0 54.0 56.0 58.0 60.0
# Data variables:
#     rho         (eco_region, lon, lat) float64 0.106 0.068 0.135 ... 0.039 0.081

# %%
ccm_sst_tau_3
# Out:
# <xarray.Dataset>
# Dimensions:     (eco_region: 15, lon: 5, lat: 5)
# Coordinates:
#   * eco_region  (eco_region) object 'Arizona/New Mexico Mountains' ... 'Wasat...
#   * lon         (lon) float64 180.0 182.0 184.0 186.0 188.0
#   * lat         (lat) float64 52.0 54.0 56.0 58.0 60.0
# Data variables:
#     rho         (eco_region, lon, lat) float64 0.138 0.063 0.034 ... 0.043 0.457

# %%
ccm_sst_tau_6
# Out:
# <xarray.Dataset>
# Dimensions:     (eco_region: 15, lon: 5, lat: 5)
# Coordinates:
#   * eco_region  (eco_region) object 'Arizona/New Mexico Mountains' ... 'Wasat...
#   * lon         (lon) float64 180.0 182.0 184.0 186.0 188.0
#   * lat         (lat) float64 52.0 54.0 56.0 58.0 60.0
# Data variables:
#     rho         (eco_region, lon, lat) float64 0.209 0.014 ... 0.126 0.455

# %%
ccm_slp_tau_1
# Out:
# <xarray.Dataset>
# Dimensions:     (eco_region: 15, lon: 5, lat: 5)
# Coordinates:
#   * eco_region  (eco_region) object 'Arizona/New Mexico Mountains' ... 'Wasat...
#   * lon         (lon) float64 180.0 182.5 185.0 187.5 190.0
#   * lat         (lat) float64 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     rho         (eco_region, lon, lat) float64 -0.068 -0.05 ... 0.023 -0.09

# %%
def test_save(ccm_array, path=''):
    print(str(ccm_array))

# %%
test_save(ccm_sst_tau_6)
# Out:
# <xarray.Dataset>
# Dimensions:     (eco_region: 15, lon: 5, lat: 5)
# Coordinates:
#   * eco_region  (eco_region) object 'Arizona/New Mexico Mountains' ... 'Wasat...
#   * lon         (lon) float64 180.0 182.0 184.0 186.0 188.0
#   * lat         (lat) float64 52.0 54.0 56.0 58.0 60.0
# Data variables:
#     rho         (eco_region, lon, lat) float64 0.209 0.014 ... 0.126 0.455

# %%
save_ccm(ccm_sst_tau_6, ['SST', 6])
# Out:
# ()
